# %% [markdown]
# # Train Your Own CNN on CIFAR
#
# In this practical, you will extend the CNN workflow from the tutorial and apply it to a more complex image dataset: CIFAR-10 (or CIFAR-100).
#
# Unlike MNIST, these images are:
#
# - RGB (3 channels instead of 1)
# - More complex (natural images rather than digits)
# That makes them harder to classify!

# %% [markdown]
# ## Load the CIFAR Dataset
#
# Load the CIFAR-10 dataset using [torchvision.datasets](https://docs.pytorch.org/vision/stable/datasets.html). Don't forget to apply the ToTensor() transform.
# Visualise a few images and their labels.
#
# __Remember__: The test set must not be used during training or model selection. It should only be used once for the final evaluation!!
#
# __Important__: CIFAR images are 32×32×3.

# %%
# add code here

# %% [markdown]
# ## Create DataLoaders
# Split the training dataset into 80/20 for training and validation.

# %%
# add code here

# %% [markdown]
# Create DataLoaders with batch size = 64 and shuffling enabled.

# %%
# add code here

# %% [markdown]
# ## Adapt the CNN Architecture - Model A
# The CNN from the tutorial will not work directly for CIFAR.
#
# You will need to modify the OurCNN class:
# - Update the input channels (MNIST: 1 channel → CIFAR: 3 channels)
# - Ensure the output layer has 10 outputs for CIFAR-10 (or 100 outputs for CIFAR-100)

# %%
# add code here

# %% [markdown]
# ### Train the Model
# Train the model for 20 epochs.
#
# Store:
# - training loss
# - validation loss
# - validation accuracy

# %%
# add code here

# %% [markdown]
# ### Learning Curves
# Plot the learning curves.
# Is the model learning (loss decreasing)? Do you see underfitting? or overfitting? or just good generalisation?
# How does performance compare to MNIST?

# %%
# add code here

# %% [markdown]
# ## Create Model B
# Create and train a new model by either:
# - Increasing the number of convolutional filters
# - Adding extra convolutional layer(s)
#
# Train in the same way as the baseline model.  Don't forget to record training loss, validation loss and validation accuracy.

# %%
# add code here

# %% [markdown]
# Plot the learning curves.  Is this model performing better than Model A?

# %%
# add code here

# %% [markdown]
# ## Create Model C
# Choose the architecture of either Model A or B.  This time train for more epochs and modify the learning rate.  If you feel particularly courageous, consider implementing Dropout (e.g., https://machinelearningmastery.com/using-dropout-regularization-in-pytorch-models/).
# Don't forget to record training loss, validation loss and validation accuracy.

# %%
# add code here

# %% [markdown]
# Plot the learning curves.  Is this model performing better than model B or the baseline? Why?

# %%
# add code here

# %% [markdown]
# ## [Optional] Create Model D
# Let's do transfer learning (as in the tutorial).  Train it for 5 epochs.  Don't forget to record training loss, validation loss and validation accuracy.

# %% [markdown]
# Plot the learning curves.

# %% [markdown]
# ## Test Generalisability of the Best Model
#
# Chose the model that performed best from Models A-D.
# Which metric will you use and why?

# %%
# add code here

# %% [markdown]
# Evaluate the selected model on the test set and calculate loss and accuracy (and plot these in a bar chart).

# %%
# add code here

# %% [markdown]
# Are the loss/accuracy values close to those in the validation dataset?  Are there any signs of overfitting?
