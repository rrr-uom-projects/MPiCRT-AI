# %% [markdown]
# # Classification using Neural Networks
#
# We will now train our a neural network classifier using PyTorch for the ORN dataset.
#
# **When working in Colab, do not forget to change your environment to have access to a GPU!**
#
#
# For completeness, here is the information we already had:
#
# The publication is:
#
# > **Normal Tissue Complication Probability (NTCP) Prediction Model for Osteoradionecrosis of the Mandible in Patients With Head and Neck Cancer After Radiation Therapy: Large-Scale Observational Cohort.**
# > By van Dijk LV, Abusaif AA, Rigert J, Naser MA, Hutcheson KA, Lai SY, Fuller CD, Mohamed ASR; on behalf on the MD Anderson Symptom Working Group. Int J Radiat Oncol Biol Phys. 2021 Oct 1;111(2):549-558. doi: 10.1016/j.ijrobp.2021.04.042. https://pubmed.ncbi.nlm.nih.gov/33965514/
#
# You can find the data in [figshare](https://figshare.com/articles/dataset/Dose-volume_histogram_DVH_parameters_of_the_mandible_for_Normal_Tissue_Complication_Probability_modelling/13568207?file=26041154).  We made a copy in our repository for your convenience.  The url for the file is:
#
# https://raw.githubusercontent.com/rrr-uom-projects/MPiCRT-AI/refs/heads/main/Data/ORN_PMCID_PMC8906058.csv
#
# And the data we will find inside is:
#
# Outcomes:
# - ORN_binary: any grade of osteoradionecrosis  <<-- This is the variable we will use in this practical!
# - ORN Grade: grade of the osteoradionecrosis
#
# Patient data:
# - Age: nr of years at treatment
# - Gender: sex of the patient
# - Subsite: where the tumour, oral cavity vs. oropharynx vs. hypopharynx/unknown-primary/larynx/nasopharynx
# - T_stage: tumour stage, related to tumour size
# - N_stage: nodal stage, related to nodal involvement
# - Dental_extraction: 0 no, 1 yes
# - Smoking_status: current, former, or never smoke
# - pack_years: nr of cigarrete packs/year
# - chemotherapy: chemotherapy info, in particular timing
# - postop_RT: definitive vs. postoperative radiotherapy
#
# DVH parameters form the mandible:
# - mean, minGy, maxGy: mean, minimum and maximum dose within the mandible bone, respectively
# - Vx: DVH metric, the volume within the mandible receiving at least x Gy, where x goes from 5 to 70 every 5 Gy
# - Dy: DVH metric, the highest dose that y% of the mandible received, where y is 2, 5 to 95 every 5, 97, 98, 99
# - Volume: volume of the mandible bone

# %% [markdown]
# Include the libraries we need and load the dataframe in a variable named **orn**.

# %%
# code here

# %% [markdown]
# ## Data preprocessing
# Let's set the categorical variables as categorical.  These include:
# - ORN_binary
# - ORN Grade
# - Gender
# - Subsite (check for consistency)
# - T_stage
# - N_stage
# - Dental_extraction
# - Smoking_status
# - chemotherapy (check for consistency)
# - postop_RT

# %%
# code here

# %% [markdown]
# Create the variables 'chemo_clean' and 'chemo_binary'  -- see practical 1

# %%
# code here

# %% [markdown]
# Create new columns 'T_stage_num' and 'N_stage_num' where you only record the number of the stage (e.g, instead of T1a record 1, or instead of N2b, 2).

# %%
# Code here

# %% [markdown]
# Create dummy variables for T_stage_num (with prefix 'T')

# %%
# Code here

# %% [markdown]
# Create dummy variables for N_stage_num (with prefix 'N')

# %%
# Code here

# %% [markdown]
# Did you created any new variable in practicals 1-3?  if so, bring the code here to have all the data in a single dataframe.

# %%
# Code here

# %% [markdown]
# Keep the variables you want to use for classification, eliminate those that are not useful for model development.

# %%
# code here

# %% [markdown]
# As we will use neural networks, as implemented in PyTorch.  These implementation require all features converted to *numerical* features.
# Please convert the categorical values into numbers.

# %%
# code here

# %% [markdown]
# ## Data Splitting
# We will predict ORN_binary to start. Divide the dataset in *training*, *validation* and *testing*.  Use 60/20/20. Double check your resulting dataset sizes are correct.
#
# Tip: use train_test_split 2 times:
# 1. split the complete dataset between training+validation vs testing
# 2. split the training+validation subset into training and validation
#
# Use testing only in the last Section to compare models.

# %% [markdown]
# # Let's do some PyTorch now
# ## Convert Data to PyTorch Tensors
#
# Neural networks in PyTorch operate on tensors rather than pandas dataframes.
#
# Convert the training and validation datasets into PyTorch tensors.

# %%
# code here

# %% [markdown]
# Move the tensors to the GPU (if available).

# %%
# code here

# %% [markdown]
# ## Define the Neural Network
#
# We will now create a feed-forward neural network.
#
# In the tutorial, the model had:
#
# - 3 hidden layers
# - 7 neurons per layer
# - ReLU activation functions
# - Sigmoid output for binary classification
#
# Now, implement a neural network class inheriting from torch.nn.Module. You can create a network similar to the one we used in the tutorial.

# %%
# code here

# %% [markdown]
# ## Define the Loss Function and Optimiser
#
# For binary classification, the most appropriate loss function is Binary Cross Entropy (BCE), as we saw in the tutorial.
# Please define the loss function using torch.nn.BCELoss and define the optimiser using Adam.
# Let's use an initial learning rate of 0.01.

# %%
# code here

# %% [markdown]
# ## Train the Neural Network
# Reuse the functions created in the tutorial:
#
# - train_1epoch
# - evaluate
#
# Now it is your time to train your neural network. Use 200 epochs to start.
#
# Store:
# - training loss
# - validation loss
# - training accuracy
# - validation accuracy
#
# Plot the learning curves.

# %%
# code here

# %%
# code here

# %% [markdown]
# ### Question time:
# Does the model appear to converge?  How can you identify that?
# Is there evidence of overfitting or underfitting?

# %% [markdown]
# Answer here.

# %% [markdown]
# Experiment with the Learning Rate
#
# Remember that the learning rate controls how quickly the optimiser updates the model parameters (how large are the steps of the blind hiker).
#
# Train the best architecture again using different learning rates:
# - 0.001
# - 0.01
# - 0.1
#
# Compare the resulting learning curves.

# %%
# add code here

# %%
# add code here

# %%
# add code here

# %% [markdown]
# ### Question time
#
# What happens when the learning rate is too large?
# What happens when it is too small?

# %% [markdown]
# Answer here

# %% [markdown]
# ## Experiment with Different Architectures
#
# Neural network performance depends strongly on the architecture.
#
# Create at least two alternative architectures by modifying:
# - number of hidden layers
# - number of neurons per layer
#
# Some examples you could try:
#
# - *Model A*: 2 hidden layers, 10 neurons per layer
# - *Model B*: 4 hidden layers, 5 neurons per layer
# - *Model C*: 5 hidden layers, 10 neurons per layer
#
# Train each model and compare their learning curves.

# %%
# code here for Model A

# %%
# code here for Model B

# %%
# code here for Model C

# %% [markdown]
# ### Question time
#
# Which architecture performs best on the validation set? Any idea why?

# %% [markdown]
# Answer here

# %% [markdown]
# ## Evaluate the best model in the test dataset
#
# Comparing the learning curves and final validation accuracy, choose the best performing model (baseline, A, B, or C... or any other you trained).
# Now, calculate the accuracy using the best model on the test dataset...

# %%
# code here

# %% [markdown]
# Is it similar to the training/validation performance?
# How good did it do?
#
#
# You finished now.
