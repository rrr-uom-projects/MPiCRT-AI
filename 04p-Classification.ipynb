# %% [markdown]
# # Classification
#
# We will now train our first classifier for the ORN dataset. For completeness, here is the information we already had:
#
# The publication is:
#
# > **Normal Tissue Complication Probability (NTCP) Prediction Model for Osteoradionecrosis of the Mandible in Patients With Head and Neck Cancer After Radiation Therapy: Large-Scale Observational Cohort.**
# > By van Dijk LV, Abusaif AA, Rigert J, Naser MA, Hutcheson KA, Lai SY, Fuller CD, Mohamed ASR; on behalf on the MD Anderson Symptom Working Group. Int J Radiat Oncol Biol Phys. 2021 Oct 1;111(2):549-558. doi: 10.1016/j.ijrobp.2021.04.042. https://pubmed.ncbi.nlm.nih.gov/33965514/
#
# You can find the data in [figshare](https://figshare.com/articles/dataset/Dose-volume_histogram_DVH_parameters_of_the_mandible_for_Normal_Tissue_Complication_Probability_modelling/13568207?file=26041154).  We made a copy in our repository for your convenience.  The url for the file is:
#
# https://raw.githubusercontent.com/rrr-uom-projects/MPiCRT-AI/refs/heads/main/Data/ORN_PMCID_PMC8906058.csv
#
# And the data we will find inside is:
#
# Outcomes:
# - ORN_binary: any grade of osteoradionecrosis  <<-- This is the variable we will use in this practical!
# - ORN Grade: grade of the osteoradionecrosis
#
# Patient data:
# - Age: nr of years at treatment
# - Gender: sex of the patient
# - Subsite: where the tumour, oral cavity vs. oropharynx vs. hypopharynx/unknown-primary/larynx/nasopharynx
# - T_stage: tumour stage, related to tumour size
# - N_stage: nodal stage, related to nodal involvement
# - Dental_extraction: 0 no, 1 yes
# - Smoking_status: current, former, or never smoke
# - pack_years: nr of cigarrete packs/year
# - chemotherapy: chemotherapy info, in particular timing
# - postop_RT: definitive vs. postoperative radiotherapy
#
# DVH parameters form the mandible:
# - mean, minGy, maxGy: mean, minimum and maximum dose within the mandible bone, respectively
# - Vx: DVH metric, the volume within the mandible receiving at least x Gy, where x goes from 5 to 70 every 5 Gy
# - Dy: DVH metric, the highest dose that y% of the mandible received, where y is 2, 5 to 95 every 5, 97, 98, 99
# - Volume: volume of the mandible bone

# %% [markdown]
# Include the libraries we need and load the dataframe in a variable named **orn**.

# %%
# code here

# %% [markdown]
# ## Data preprocessing
# Let's set the categorical variables as categorical.  These include:
# - ORN_binary
# - ORN Grade
# - Gender
# - Subsite (check for consistency)
# - T_stage
# - N_stage
# - Dental_extraction
# - Smoking_status
# - chemotherapy (check for consistency)
# - postop_RT

# %%
# code here

# %% [markdown]
# Create the variables 'chemo_clean' and 'chemo_binary'  -- see practical 1

# %%
# code here

# %% [markdown]
# Create new columns 'T_stage_num' and 'N_stage_num' where you only record the number of the stage (e.g, instead of T1a record 1, or instead of N2b, 2).

# %%
# Code here

# %% [markdown]
# Create dummy variables for T_stage_num (with prefix 'T')

# %%
# Code here

# %% [markdown]
# Create dummy variables for N_stage_num (with prefix 'N')

# %%
# Code here

# %% [markdown]
# Did you created any new variable in practicals 1-3?  if so, bring the code here to have all the data in a single dataframe.

# %%
# Code here

# %% [markdown]
# Keep the variables you want to use for classification, eliminate those that are not useful for model development.

# %%
# code here

# %% [markdown]
# As we will use SVM and RFC for our classifiers, as implemented in sklearn.  These implementation require all features converted to *numerical* features.
# Please convert the categorical values into numbers.

# %%
# code here

# %% [markdown]
# ## Data Splitting
# We will predict ORN_binary to start. Divide the dataset in *training*, *validation* and *testing*.  Use 60/20/20. Double check your resulting dataset sizes are correct.
#
# Tip: use train_test_split 2 times:
# 1. split the complete dataset between training+validation vs testing
# 2. split the training+validation subset into training and validation
#
# Use testing only in the last Section to compare SVM vs RFC.

# %%
# code here

# %% [markdown]
# ## SVMs
# Using only the training dataset, you will train a number of SVMs. We will compare their performance in the validation dataset.  To be able to compare them, use a different name for each model!
#
# As first SVM, train a model with rbf and gamma 0.5 as in the tutorial.

# %%
# code here

# %% [markdown]
# Now, try a different kernel, for example poly, degree 3.
#
# Tip: check scikit's user guide page, https://scikit-learn.org/stable/modules/svm.html, or their documentation pages https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC

# %%
# code here

# %% [markdown]
# Implement other SVMs here.  Either change SVM's hyper parameters (e.g., C) or change the training data itself.  Use as many code cells as you need.

# %%
# code here

# %%
# code here

# %%
# code here

# %% [markdown]
# ### Which is the best SVM
# Using the validation dataset and accuracy as evaluation metric, compare the performance of all the SVMs you trained above.  Identify the one that performed the best.

# %%
# code here

# %% [markdown]
# Find out in what balanced accuracy score and F1-score are and use them to compare the SVMs.
#
# Tip: check https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics
#
# Is the most accurate SVM (identified above) still performing well according to the other evaluation metrics?

# %%
# code here for balanced accuracy score

# %%
# code here for F1-score

# %% [markdown]
# Choose one of the SVMs as your best model.
# Did their performance change between the metrics?  If so, why did you choose one metric above the other?

# %% [markdown]
# Answer here

# %% [markdown]
# ## RFC
# Use RandomForestClassifier now.  Using only the training dataset, you will train a number of RFCs and compare their performance, as you just did with SVMs. Use a different name for each model!
#
# Start with 100 trees as done in the tutorial

# %%
# code here

# %% [markdown]
# Now, train a new RFC with a different number of trees

# %%
# code here

# %% [markdown]
# Select and change other hyperparameter for the forest, for example, you could limit the tree depth
#
# Tip: use the guide pages https://scikit-learn.org/stable/modules/ensemble.html#random-forests-and-other-randomized-tree-ensembles and reference pages https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier
#
# Use as many code cells as you need.

# %%
# code here

# %%
# code here

# %% [markdown]
# ### Which is the best RFC?
# Using the validation dataset and accuracy as evaluation metric, compare the performance of all the RFCs you trained above.  Identify the one that performed the best.

# %%
# code here

# %% [markdown]
# Evaluate using balanced accuracy score

# %%
# code here

# %% [markdown]
# Evaluate using F1 score

# %%
# code here

# %% [markdown]
# Which RFC did you choose as best?  Did their performance change between the metrics?  If so, why did you choose one metric above the other?

# %% [markdown]
# Answer these questions here

# %% [markdown]
# ## SVM or RFC?
# Now, using your test dataset and accuracy as metric, compare the performance of the best SVM vs the best RFC.

# %%
# Code here

# %% [markdown]
# Now evaluate it with balanced accuracy score

# %%
# code here

# %% [markdown]
# And finally, with F1-score

# %%
# code here

# %% [markdown]
# Which model worked best?  Is this what you were expecting?

# %% [markdown]
# Answer here.
